# %% [markdown]
# # Analisando dados de produção hospitalar

# %% [markdown]
# ### 1.2

# %%
import pandas as pd

# %%
# dados é um DataFrame
dados = pd.read_csv("/content/A150850189_28_143_208.csv", encoding="ISO-8859-1",
            skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr  ...     2021/Ago    2021/Set         Total
# 0          11 Rondônia        -        -  ...   7371334.84  1682801.60  1.088060e+09
# 1              12 Acre        -        -  ...   1196754.85           -  4.752903e+08
# 2          13 Amazonas        -        -  ...  13806958.66  5292323.36  2.061943e+09
# 3           14 Roraima        -        -  ...   2907871.07  1496814.75  3.525463e+08
# 4              15 Pará        -        -  ...  20837865.89  4620263.03  4.968812e+09
#
# [5 rows x 293 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2021/Set         Total
# 22   43 Rio Grande do Sul        -  ...  25200345.68  1.361334e+10
# 23  50 Mato Grosso do Sul        -  ...   2445267.12  2.516383e+09
# 24         51 Mato Grosso        -  ...   7325067.61  2.386584e+09
# 25               52 Goiás        -  ...  18860370.17  5.380179e+09
# 26    53 Distrito Federal        -  ...  13173812.37  2.778457e+09
#
# [5 rows x 293 columns]

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2021/Mai    8.727186e+07
# 2021/Jun    7.759041e+07
# 2021/Jul    6.084629e+07
# 2021/Ago    4.388572e+07
# Total       6.852321e+09
# Length: 170, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 293 entries, Unidade da Federação to Total
# dtypes: float64(170), object(123)
# memory usage: 61.9+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %% [markdown]
# ### 1.3

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42502172.22
# 19   180097396.03
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21070201.36
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26645398.357037038

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

axis = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")

plt.show()

# %% [markdown]
# Desafio 1: executar o gráfico anterior com o mês mais recente

# %% [markdown]
# Desafio 2: deixar as legendas ânguladas (0, 45 etc) para facilitar a leitura

# %% [markdown]
# ### 2.1

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Ago    2021/Set         Total
# 0          11 Rondônia        -        -  ...  7371334.84  1682801.60 1088059702.25
# 1              12 Acre        -        -  ...  1196754.85           -  475290315.34
# 2          13 Amazonas        -        -  ... 13806958.66  5292323.36 2061943006.93
# 3           14 Roraima        -        -  ...  2907871.07  1496814.75  352546288.71
# 4              15 Pará        -        -  ... 20837865.89  4620263.03 4968811817.17
#
# [5 rows x 293 columns]

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai', '2021/Jun',
#        '2021/Jul', '2021/Ago', '2021/Set', 'Total'],
#       dtype='object', length=293)

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis[:5]
# Out:
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Ago         Total
# 0          11 Rondônia   4209.37  ...  7371334.84 1088059702.25
# 1              12 Acre  10470.07  ...  1196754.85  475290315.34
# 2          13 Amazonas  35752.72  ... 13806958.66 2061943006.93
# 3           14 Roraima   4785.91  ...  2907871.07  352546288.71
# 4              15 Pará 181159.29  ... 20837865.89 4968811817.17
#
# [5 rows x 171 columns]

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Ago         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7371334.84 1088059702.25
# 12 Acre               10470.07  14001.71  ...  1196754.85  475290315.34
# 13 Amazonas           35752.72  45570.64  ... 13806958.66 2061943006.93
# 14 Roraima             4785.91  11858.63  ...  2907871.07  352546288.71
# 15 Pará              181159.29 433414.74  ... 20837865.89 4968811817.17
#
# [5 rows x 170 columns]

# %%
dados_usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
dados_usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %%
dados_usaveis.iloc[1]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))

# %%
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
dados_usaveis.T.plot(figsize=(12,6))

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia  ...  53 Distrito Federal
# 2021/Mai               17659855.79  ...          32434557.27
# 2021/Jun               14435903.47  ...          27196457.00
# 2021/Jul               11834435.10  ...          26265515.44
# 2021/Ago                7371334.84  ...          22156437.60
# Total                1088059702.25  ...        2778456616.77
#
# [5 rows x 27 columns]

# %%
dados_usaveis = dados_usaveis.drop("Total", axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Jul    2021/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ... 11834435.10  7371334.84
# 12 Acre               10470.07  14001.71  ...  2302711.01  1196754.85
# 13 Amazonas           35752.72  45570.64  ... 21614943.55 13806958.66
# 14 Roraima             4785.91  11858.63  ...  3320807.96  2907871.07
# 15 Pará              181159.29 433414.74  ... 33718084.12 20837865.89
#
# [5 rows x 169 columns]

# %%
dados_usaveis.T.plot(figsize=(12,6))

# %%
dados_usaveis.T
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37   10470.07  ...   179395.82            191951.47
# 2007/Set                 16397.03   14001.71  ...   418053.58            769966.25
# 2007/Out                133645.19   86200.85  ...  1198730.25           2165619.56
# 2007/Nov                346912.84  301323.68  ...  2712117.54           3813256.48
# 2007/Dez                711758.31  769612.36  ...  9293914.78           7121965.42
# ...                           ...        ...  ...         ...                  ...
# 2021/Abr              17753851.45 5002272.59  ... 68630407.92          35641761.42
# 2021/Mai              17659855.79 4326882.24  ... 69467332.76          32434557.27
# 2021/Jun              14435903.47 3458187.11  ... 67162348.93          27196457.00
# 2021/Jul              11834435.10 2302711.01  ... 57891285.60          26265515.44
# 2021/Ago               7371334.84 1196754.85  ... 44939821.34          22156437.60
#
# [169 rows x 27 columns]

# %% [markdown]
# Desafio: reposicionar a legenda. Dentro? Fora? Onde?

# %% [markdown]
# Desafio: retocar a nossa visualização.

# %% [markdown]
# Desafio: colocar títulos nos dois eixos.

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Jul    2021/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ... 11834435.10  7371334.84
# 12 Acre               10470.07  14001.71  ...  2302711.01  1196754.85
# 13 Amazonas           35752.72  45570.64  ... 21614943.55 13806958.66
# 14 Roraima             4785.91  11858.63  ...  3320807.96  2907871.07
# 15 Pará              181159.29 433414.74  ... 33718084.12 20837865.89
#
# [5 rows x 169 columns]

# %%
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:5]
# Out:
#                       2007/Ago  2007/Set  ...    2021/Jul    2021/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ... 11834435.10  7371334.84
# 12 Acre               10470.07  14001.71  ...  2302711.01  1196754.85
# 13 Amazonas           35752.72  45570.64  ... 21614943.55 13806958.66
# 14 Roraima             4785.91  11858.63  ...  3320807.96  2907871.07
# 15 Pará              181159.29 433414.74  ... 33718084.12 20837865.89
#
# [5 rows x 169 columns]

# %%
dados_usaveis[:7].T.plot(figsize=(10,6))

# %%
dados_usaveis.sample(n=7)
# Out:
#                       2007/Ago   2007/Set  ...     2021/Jul    2021/Ago
# Unidade da Federação                       ...
# 16 Amapá              33672.74  104822.98  ...   4136950.62  1875241.91
# 52 Goiás             179395.82  418053.58  ...  57891285.60 44939821.34
# 11 Rondônia            4209.37   16397.03  ...  11834435.10  7371334.84
# 12 Acre               10470.07   14001.71  ...   2302711.01  1196754.85
# 51 Mato Grosso        63562.50  232444.62  ...  29364200.76 19849249.43
# 41 Paraná            554800.22 1431708.01  ... 119408026.56 91187722.64
# 26 Pernambuco        400640.85 1088340.42  ...  89156304.23 71625844.36
#
# [7 rows x 169 columns]

# %%
dados_usaveis.sample(7)
# Out:
#                         2007/Ago   2007/Set  ...     2021/Jul     2021/Ago
# Unidade da Federação                         ...
# 35 São Paulo          1665349.90 4434168.64  ... 404373175.61 301986341.98
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  20711974.43  11302985.98
# 14 Roraima               4785.91   11858.63  ...   3320807.96   2907871.07
# 28 Sergipe              27453.63   78565.19  ...   7751833.41   4636420.57
# 23 Ceará               357904.65  572356.18  ...  57727138.38  35650007.47
# 22 Piauí               220788.25  353468.67  ...  19972846.10  15220885.72
# 43 Rio Grande do Sul  1049252.33 3182913.14  ... 112805351.92  74954589.62
#
# [7 rows x 169 columns]

# %%
dados_usaveis.sample(7).T.plot(figsize=(10,6))

# %%
# pseudo aleatorio... pseudo randomness
# 53874 = seed
# regra semente / 10, semente * 3 / 2
# 80811 
# regra 8081, 121216

# %%
import numpy as np

np.random.seed(524387)
dados_usaveis.sample(n=7)
# Out:
#                       2007/Ago   2007/Set  ...     2021/Jul     2021/Ago
# Unidade da Federação                       ...
# 17 Tocantins           4113.76   76633.06  ...   4610170.61   2304080.49
# 26 Pernambuco        400640.85 1088340.42  ...  89156304.23  71625844.36
# 31 Minas Gerais      971394.37 2861781.50  ... 194734136.81 139157823.59
# 22 Piauí             220788.25  353468.67  ...  19972846.10  15220885.72
# 25 Paraíba            97352.78  368130.43  ...  24925842.39  16167879.55
# 29 Bahia             135146.36  448349.75  ...  95691895.48  61645689.06
# 42 Santa Catarina    693955.05 1092964.12  ...  70531971.21  48884998.15
#
# [7 rows x 169 columns]

# %%
dados_dos_7_estados = dados_usaveis.sample(n=7)
dados_dos_7_estados.T.plot(figsize=(10,6))

# %%
dados_usaveis["Total"] = dados_usaveis.sum(axis = 1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Ago         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7371334.84 1086376296.32
# 12 Acre               10470.07  14001.71  ...  1196754.85  475289031.52
# 13 Amazonas           35752.72  45570.64  ... 13806958.66 2056647852.16
# 14 Roraima             4785.91  11858.63  ...  2907871.07  351049060.27
# 15 Pará              181159.29 433414.74  ... 20837865.89 4964173018.54
#
# [5 rows x 170 columns]

# %% [markdown]
# Desafio: ordenar nosso DataFrame para que na primeira linha tenha a linha com maior gasto, e na última com menor gasto (ordenação)

# %% [markdown]
# Desafio: adicionar uma coluna com a região de cada estado.

# %% [markdown]
# Desafio: adicione seu estado nessa lista de 7 estados (`dados_dos_7_estados`).

# %% [markdown]
# ### 3.2

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Ago         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7371334.84 1086376296.32
# 12 Acre               10470.07  14001.71  ...  1196754.85  475289031.52
# 13 Amazonas           35752.72  45570.64  ... 13806958.66 2056647852.16
# 14 Roraima             4785.91  11858.63  ...  2907871.07  351049060.27
# 15 Pará              181159.29 433414.74  ... 20837865.89 4964173018.54
#
# [5 rows x 170 columns]

# %%
ordenados_por_total = dados_usaveis.sort_values(by="Total", ascending=False)
ordenados_por_total = ordenados_por_total.drop("Total", axis=1)
# ordenados_por_total.drop("Total", axis=1, inplace=True)
ordenados_por_total.head(5)
# Out:
#                        2007/Ago   2007/Set  ...     2021/Jul     2021/Ago
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 404373175.61 301986341.98
# 31 Minas Gerais       971394.37 2861781.50  ... 194734136.81 139157823.59
# 41 Paraná             554800.22 1431708.01  ... 119408026.56  91187722.64
# 43 Rio Grande do Sul 1049252.33 3182913.14  ... 112805351.92  74954589.62
# 33 Rio de Janeiro     469469.34  921646.57  ... 113660882.20  94137361.39
#
# [5 rows x 169 columns]

# %%
ordenados_por_total.head(5).T.plot(figsize=(10,6))

# %% [markdown]
# Desafio: adicionar seu estado aos 5 estados existentes, e plotar.

# %%
colunas_interessadas = ordenados_por_total.columns[6:]
ordenados_por_total = ordenados_por_total[colunas_interessadas]

# %%
ordenados_por_total.head(5).T.plot(figsize=(10,6))

# %% [markdown]
# Desafio: adicionar seu estado.

# %% [markdown]
# Desafio: deixar o gráfico mais refinado.

# %% [markdown]
# Desafio: pesquisar o `sort_index`.

# %% [markdown]
# Desafio: googlar os casos de dengue do Brasil e verificar se existe algum padrão com os gastos encontrados aqui.

# %% [markdown]
# Desafio: plotar somente os estados de uma região do Brasil.
