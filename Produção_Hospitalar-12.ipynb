# %% [markdown]
# # Analisando dados de produção hospitalar

# %% [markdown]
# ### 1.2

# %%
import pandas as pd

# %%
# dados é um DataFrame
dados = pd.read_csv("/content/A152918189_28_143_208.csv", encoding="ISO-8859-1",
            skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dados.head()
# Out:
#   Unidade da Federação    2008/Jan  ...     2021/Set         Total
# 0          11 Rondônia  1388528.39  ...  10345616.78 1088059702.25
# 1              12 Acre   902416.00  ...            -  475290315.34
# 2          13 Amazonas  4735529.42  ...  19840265.30 2061943006.93
# 3           14 Roraima   657889.53  ...   3150835.05  352546288.71
# 4              15 Pará 18864744.11  ...  14569318.55 4968811817.17
#
# [5 rows x 167 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação    2008/Jan  ...      2021/Set          Total
# 22   43 Rio Grande do Sul 30931325.46  ...  120016574.60 13613341350.00
# 23  50 Mato Grosso do Sul  5377392.11  ...   32338424.49  2516383489.01
# 24         51 Mato Grosso  4795299.01  ...   27274369.25  2386584382.72
# 25               52 Goiás 15310637.29  ...   64176809.02  5380180598.64
# 26    53 Distrito Federal  4745919.19  ...   28509985.96  2778456616.77
#
# [5 rows x 167 columns]

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2021/Mai     79540074.51
# 2021/Jun     82724335.66
# 2021/Jul     81601322.73
# 2021/Ago     75035922.89
# Total      6852328259.77
# Length: 164, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 167 entries, Unidade da Federação to Total
# dtypes: float64(164), object(3)
# memory usage: 35.4+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2021/Mai     79540074.51
# 2021/Jun     82724335.66
# 2021/Jul     81601322.73
# 2021/Ago     75035922.89
# Total      6852328259.77
# Length: 164, dtype: float64

# %% [markdown]
# ### 1.3
